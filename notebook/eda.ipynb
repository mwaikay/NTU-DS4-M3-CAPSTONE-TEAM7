# %%
import pandas as pd
import numpy as np

# %%
df_train = pd.read_csv('../data/train.csv')
# Out:
# C:\Users\yizhe\AppData\Local\Temp\ipykernel_4424\788172147.py:1: DtypeWarning: Columns (41) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_train = pd.read_csv('../data/train.csv')

# %%
df_train.head()
# Out:
#        id Tranc_YearMonth             town  flat_type block       street_name  \
# 0   88471         2016-05  KALLANG/WHAMPOA     4 ROOM    3B  UPP BOON KENG RD
# 1  122598         2012-07           BISHAN     5 ROOM   153      BISHAN ST 13
# 2  170897         2013-07      BUKIT BATOK  EXECUTIVE  289B    BT BATOK ST 25
# 3   86070         2012-04           BISHAN     4 ROOM   232      BISHAN ST 22
# 4  153632         2017-12           YISHUN     4 ROOM   876      YISHUN ST 81
#
#   storey_range  floor_area_sqm  flat_model  lease_commence_date  ...  vacancy  \
# 0     10 TO 12            90.0     Model A                 2006  ...       78
# 1     07 TO 09           130.0    Improved                 1987  ...       45
# 2     13 TO 15           144.0   Apartment                 1997  ...       39
# 3     01 TO 05           103.0     Model A                 1992  ...       20
# 4     01 TO 03            83.0  Simplified                 1987  ...       74
#
# ...

# %%
df_train.dtypes.value_counts()
# Out:
# int64      32
# float64    25
# object     20
# Name: count, dtype: int64

# %%
num_col = df_train.select_dtypes(include=['int64']).columns
float_col = df_train.select_dtypes(include=['float64']).columns
cat_col = df_train.select_dtypes(include=['object']).columns

# %% [markdown]
# Clean num_col first:
#
# 1. Check negative values
# 2. check logic violations

# %%
num_col_null_counts = df_train[num_col].isnull().sum()
num_col_null_counts[num_col_null_counts != 0]
# Out:
# Series([], dtype: int64)

# %%
df_train[num_col].head()
# Out:
#        id  lease_commence_date  Tranc_Year  Tranc_Month  mid_storey  lower  \
# 0   88471                 2006        2016            5          11     10
# 1  122598                 1987        2012            7           8      7
# 2  170897                 1997        2013            7          14     13
# 3   86070                 1992        2012            4           3      1
# 4  153632                 1987        2017           12           2      1
#
#    upper  mid  hdb_age  max_floor_lvl  ...  3room_rental  other_room_rental  \
# 0     12   11       15             25  ...             0                  0
# 1      9    8       34              9  ...             0                  0
# 2     15   14       24             16  ...             0                  0
# 3      5    3       29             11  ...             0                  0
# 4      3    2       34              4  ...             0                  0
#
# ...

# %%
non_negative_num_col = [col for col in num_col if any(keyword in col.lower() for keyword in ['count', 'num', 'quantity', 'amount', 'total'])]
